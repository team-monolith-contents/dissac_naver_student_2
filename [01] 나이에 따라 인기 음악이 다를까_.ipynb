# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">나도 슈퍼스타!</div>
#     <div style="font-weight: bold; font-size: 20px">[01] 나이에 따라 인기 음악이 다를까?</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <학습 순서>
#     <br>
#     - 네이버의 음악 서비스 네이버 바이브의 데이터를 탐색하여 연령대별, 계절별로 어떤 음악이 인기가 많은지 알아봅시다.<br>
#     - 네이버 바이브 데이터의 분석 결과를 창의적으로 해석해봅시다.<br>
#     - 인기 음악 분석 결과를 바탕으로 오디션 음악을 선정해주는 프로그램을 만들어봅시다.<br>
#
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>0. 네이버 바이브란?</h2>
# </div>

# %% [markdown]
# ![image.png](attachment:17cc0ad9-a81d-4278-9d82-567ad5aebffb.png)
# <br>
#
# 코들이가 슈퍼스타N에 나가서 우승할 수 있으려면 어떤 음악을 골라야할까요?
# 사람들에게 인기가 높았던 음악을 선택하는 것이 유리할 것 같은데요. 인기가 많은 음악을 찾기 위해서는 우리가
# 평소에 자주 사용하는 음악 서비스에 남아 있는 데이터를 활용해야 할 것입니다.
#
# 여러분은 평소에 어떤 음악을 듣나요? 음악을 듣기 위해 어떤 서비스를 이용하나요?
# 다음의 내용들을 포함하여 나의 경험을 말해봅시다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 1</div>
#     <br>
# 어떤 가수의 어떤 음악을 자주 듣나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 2</div>
#     <br>
# 음악을 듣기 위해 사용하는 서비스(어플, 웹사이트)는 무엇인가요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# **네이버 바이브(Naver Vibe)** 는 네이버의 음악 스트리밍 서비스입니다.
# 사람들이 네이버 바이브의 어플이나 홈페이지에 들어가서 음악을 들으면 인터넷상에 데이터가 남게 되는데요,
# 누가, 몇 시에, 무슨 음악을, 몇 초 동안 들었는지 등의 데이터가 남습니다. 이렇게 사용자가 인터넷에 접속해서
# 남기는 발자국 같은 데이터를 **'로그 데이터'** 라고 합니다.
# 이번 프로젝트에서는 네이버 바이브의 사용자들이 남긴 로그 데이터를 보고 연령별, 월별로 어떤 음악이 인기
# 가 많은지 분석해볼 거예요. 그리고 코들이가 계절에 따라 인기 음악을 선택할 수 있도록 도와주는 프로그램
# 을 만들어보겠습니다.

# %% [markdown]
# 여러분은 어떤 음악을 좋아하나요? 여러분이 좋아하는 음악과 선생님이 좋아하는 음악은 비슷할까요? 2019
# 년 1년 간 가장 많은 재생수를 기록한 음악은 무엇일까요? 10대는 어떤 가수의 어떤 음악을 많이 들었을까요?<div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 연령대별 인기 음악 추측해보기</h2>
# </div>

# %% [markdown]
# 여러분은 어떤 음악을 좋아하나요? 여러분이 좋아하는 음악과 선생님이 좋아하는 음악은 비슷할까요? 2019
# 년 1년 간 가장 많은 재생수를 기록한 음악은 무엇일까요? 10대는 어떤 가수의 어떤 음악을 많이 들었을까요?
# 데이터를 살펴보기 전에 우리는 머릿속으로 추측을 해볼 수 있어요.
# 다음의 질문에 대한 여러분의 추측을 말해보세요

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 1</div>
#     <br>
# 2019년 1년 간 가장 많은 재생수를 기록한 음악은 무엇일 것 같나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 2</div>
#     <br>
# 2019년 1년 간 10대가 가장 많이 들은 음악은 무엇일 것 같나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 3</div>
#     <br>
# 2019년 1년 간 10대가 가장 많이 들은 가수는 누구일 것 같나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 네이버 바이브 데이터로 연령대별 인기 음악 분석 및 해석하기</h2>
# </div>

# %% [markdown]
# 자, 그럼 여러분의 추측이 맞았는지 틀렸는지, 데이터를 직접 보면서 한번 알아볼까요?
#
# 데이터를 살펴보기 위해선 먼저 Pandas 라이브러리와 Pyplot 라이브러리를 불러와야겠죠?
# 아래 셀을 실행하여 필요한 라이브러리들을 가져와봅시다.

# %%
# 라이브러리 불러오기
import pandas as pd  # Pandas를 pd로 축약하여 불러옵니다
import matplotlib.pyplot as plt  # Pyplot을 plt로 축약하여 불러옵니다

# %% [markdown]
# 여러분이 살펴보게 될 데이터는 **'네이버 VIBE 재생 수 및 연령별 선호도.xlsx'** 입니다.
# `pd.read_excel(파일 경로)` 함수를 활용하여 데이터가 저장된 엑셀 파일을 불러옵니다.

# %%
# 엑셀 파일을 데이터프레임 형식으로 불러오기
df = pd.read_excel('https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/data/%EB%84%A4%EC%9D%B4%EB%B2%84+VIBE+%EC%9E%AC%EC%83%9D+%EC%88%98+%EB%B0%8F+%EC%97%B0%EB%A0%B9%EB%B3%84+%EC%84%A0%ED%98%B8%EB%8F%84.xlsx')

# %% [markdown]
# 잠깐 데이터를 살펴볼까요? 이것은 2019년 1월부터 12월까지 재생수를 기준으로 1위부터 100위까지의 음악
# 들을 대상으로 만든 데이터입니다. 첫 번째 열에는 노래 제목이, 두 번째 열에는 ‘아티스트’라고 해서 가수 이름
# 이, 세 번째 열에는 재생 수가 있어요. 두 번째 행인 ‘작은 것들을 위한 시’를 볼까요? 방탄소년단의 노래이고,
# 재생 수는 약 6백 만 번이네요.

# %%
df
# Out:
#                                            제목                  아티스트     재생 수  \
# 0   작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)         방탄소년단, Halsey  6031368
# 1                                        2002            Anne-Marie  5278763
# 2                           사계 (Four Seasons)          태연 (TAEYEON)  4951443
# 3                                주저하는 연인들을 위해                   잔나비  4694413
# 4                                     bad guy         Billie Eilish  4145969
# ..                                        ...                   ...      ...
# 95                                        신용재                    하은  1486363
# 96                           Into the Unknown  Idina Menzel, Aurora  1476330
# 97                          짐살라빔 (Zimzalabim)     Red Velvet (레드벨벳)  1456467
# 98                                 불티 (Spark)          태연 (TAEYEON)  1450018
# 99                                   MILLIONS                WINNER  1440312
#
# ...

# %% [markdown]
# 이렇게 숫자로 보니까 잘 모르겠죠?
# 그럴 땐 그래프를 활용하여 데이터를 알아보기 좋게 표현할 수 있습니다.
#
# 특히 **막대 그래프** 는 하나의 주제를 가지고 서로 다른 대상을 비교할 때 좋아요. 우리는 재생수, 연령대별 선호도처럼
# 특정한 주제를 가지고 100개의 음악을 비교해볼 거예요.
#
# `df.plot(x, y, kind='bar')` 함수와 `plt.show()` 함수를 사용하면 막대 그래프를 생성하여 출력할 수 있습니다.
# x와 y에 원하는 열의 이름을 설정하여 데이터를 분석해봅시다.
#
# 데이터에 있는 모든 열의 이름은 아래와 같습니다. 이를 참고하여 막대 그래프를 그려보세요.

# %%
df.columns
# Out:
# Index(['제목', '아티스트', '재생 수', '10대 미만 선호도', '10대 선호도', '20대 선호도', '30대 선호도',
#        '40대 선호도', '50대 선호도', '60대 이상 선호도'],
#       dtype='object')

# %% [markdown]
# ### **1) 2019년 1년 간 가장 많은 재생수를 기록한 음악은 무엇일까?**

# %% [markdown]
# 2019년 일 년 동안 가장 인기 있었던 음악을 알기 위해서 그래프를 그려볼 거예요. ‘가로축’을 ‘제목’, ‘계열 값’을
# ‘재생 수’로 만들어보세요.

# %%
# 가로축이 '제목', 계열 값이 '재생 수'인 막대 그래프를 그려봅시다. (figsize=(18,8))

# %% [markdown]
# 2019년 가장 인기가 많은 음악은 무엇이었나요? ‘작은 것들을 위한 시’가 1위였네요.

# %% [markdown]
# ### **2) 2019년 1년 동안 10대가 가장 많이 찾은 음악은 무엇일까요?**

# %% [markdown]
# 이번에는 연령대별로 인기 음악을 알아볼 거예요. 여러분은 10대니까 10대 선호도를 알아볼게요. ‘가로축’은
# 그대로 ‘제목’으로 두고 ‘계열 값’에 ‘10대 선호도’를 넣어주세요.

# %%
# 가로축이 '제목', 계열 값이 '10대 선호도'인 막대 그래프를 그려봅시다. (figsize=(18,8))

# %% [markdown]
# 2019년 10대에게 가장 인기가 많은 음악은 무엇이었나요?
# 위의 그래프는 재생수에 따라 정렬되어 있어 10대 선호도가 가장 높은 음악을 찾기가 어려워요.
# 그래서 10대 선호도를 기준으로 표를 다시 정렬한 뒤 그래프를 그려보도록 해요.

# %%
# 10대 선호도에 따라 값을 정렬해봅시다.
'''
df.sort_values(정렬할 데이터, inplace=True, axcending=False)
    - inplace=True: 정렬한 결과를 원본 데이터에 반영해줍니다. 
    - ascending=False: 내림차순으로 정렬해줍니다.
'''

# %%
# 정렬한 결과로 다시 막대 그래프를 그려봅시다.

# %% [markdown]
# ### **3) 2019년 1년 동안 10대가 가장 많이 찾은 음악을 부른 가수는 누구일까요?**

# %% [markdown]
# 이번에는 음악이 아니라 가수를 살펴볼 거예요. 10대에게 인기가 많았던 가수를 살펴보기 위해서 ‘가로축’은
# ‘아티스트’, ‘계열 값’은 그대로 ‘10대 선호도’로 해보세요.

# %%
# 가로축이 '아티스트', 계열 값이 '10대 선호도'인 막대 그래프를 그려봅시다.(figsize=(18,8))

# %% [markdown]
# 2019년 가장 인기가 많은 가수는 누구였나요? ‘전상근’과 ‘창모’가 1, 2위를 차지하고 있네요.
#
# 여러분의 추측이 맞았나요? 데이터를 발견한 사실을 워크시트에 적어보세요.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 1</div>
#     <br>
# 2019년 1년 간 가장 많은 재생수를 기록한 음악은 무엇이었나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 2</div>
#     <br>
# 2019년 1년 간 10대가 가장 많이 들은 음악은 무엇이었나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 3</div>
#     <br>
# 2019년 1년 간 10대가 가장 많이 들은 가수는 누구였나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">🚄 쉬어가기 (1)</div>
#     <div style="font-weight: bold; font-size: 15px">
#         &ensp; 사물인터넷 전문가란?</div>
#
# </div>

# %% [markdown]
# **사물인터넷(IoT: Internet of Things)** 은 여러 사물을 인터넷으로 연결하여서 새로운 기능을 제공하는 것을 의
# 미합니다. 우리 삶에서는 어떻게 사용될까요?
#
# 아침이 되어 해가 밝아옵니다. 빛 감지 센서가 이를 감지하고 스마트 스피커에서는 당신이 좋아하는 가수의 노래를
# 틀어 잠에서 깨워줍니다. 침대에서 일어나 화장실로 가는데 스마트홈은 당신의 이동경로를 파악해서 자동으로
# 화장실 불을 켜줍니다. 냉장고는 당신이 지난 밤 깊은 잠에 들지 못한 것을 알아내서 피로회복에 좋은 재료들로
# 아침 식단을 추천해줍니다. 재료가 떨어지면 알아서 인터넷으로 필요한 재료를 구매하기도 합니다.
#
# 영화에나 나올 법한 이야기라고요? 우리 집에 있는 모든 사물이 인터넷으로 연결된다면 충분히 가능한 이야기입니다!
#
# 사물인터넷은 가정뿐 아니라 교통, 건축, 의료, 금융 등 다양한 분야에서 활용되고 있으며 앞으로 더 확대될 것입니다.
#
#
# 사물인터넷 전문가는 이를 위해 다양한 사물에 센서를 붙이고 이들 사물이 서로 정보를 인터넷으로 주고받을
# 수 있도록 하는 기술을 개발하는 역할을 합니다. 이를 위해서는 컴퓨터와 기계를 다룰 수 있는 능력, 다양한
# 사물인터넷을 생각해낼 수 있는 응용력과 창의력이 필요합니다!
